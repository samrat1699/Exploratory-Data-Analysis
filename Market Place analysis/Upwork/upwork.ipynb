# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv("1st.csv")
df2 = pd.read_csv("2nd.csv")
df3 = pd.read_csv('3rd.csv')
df1.head()
# Out:
#    connect_price            created_on               tz_date  \
# 0              6  2023-01-01T17:33:29Z  2023-01-01T17:33:29Z
# 1              2  2023-01-01T17:38:19Z  2023-01-01T17:38:19Z
# 2              4  2023-01-01T17:38:17Z  2023-01-01T17:38:17Z
# 3              2  2023-01-01T17:38:03Z  2023-01-01T17:38:03Z
# 4              4  2023-01-01T17:37:54Z  2023-01-01T17:37:54Z
#
#              duration    engagement  freelancers_to_hire  amount_amount  \
# 0  More than 6 months  30+ hrs/week                    1            NaN
# 1   Less than 1 month           NaN                    1           30.0
# 2   Less than 1 month           NaN                    1          100.0
# 3       3 to 6 months           NaN                    1          500.0
# 4       1 to 3 months           NaN                    5          350.0
#
#    hourly_rate          type        job_ts  ... total_freelancers_to_hire  \
# 0         30.0        hourly  1.672590e+12  ...                         1
# ...

# %% [raw]
# created_on ,tz_date(Data type error)

# %%
df3.shape
# Out:
# (4996, 27)

# %%
df3.head()
# Out:
#    connect_price            created_on               tz_date  \
# 0              6  2023-01-03T11:56:21Z  2023-01-03T11:56:21Z
# 1              4  2023-01-03T11:57:00Z  2023-01-03T11:57:00Z
# 2              4  2023-01-03T11:56:51Z  2023-01-03T11:56:51Z
# 3              6  2023-01-03T11:56:18Z  2023-01-03T11:56:18Z
# 4              6  2023-01-03T11:55:59Z  2023-01-03T11:55:59Z
#
#              duration             engagement  enterprise_job  \
# 0       3 to 6 months  Less than 30 hrs/week           False
# 1   Less than 1 month                    NaN           False
# 2   Less than 1 month                    NaN           False
# 3  More than 6 months                    NaN           False
# 4  More than 6 months           30+ hrs/week           False
#
#    freelancers_to_hire  amount_amount  hourly_rate          type  ...  \
# 0                    2            NaN         30.0        hourly  ...
# 1                    1          150.0          NaN  fixed_budget  ...
# ...

# %%
df = pd.concat([df1,df2, df3], ignore_index=True, sort=False)
df = df.csv("upwork.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 df = pd.concat([df1,df2, df3], ignore_index=True, sort=False)
# ----> 2 df = df.csv("upwork.csv")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'csv'

# %%
df.shape
# Out:
# (14981, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14981 entries, 0 to 14980
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   connect_price                       14981 non-null  int64
#  1   created_on                          14981 non-null  object
#  2   tz_date                             14981 non-null  object
#  3   duration                            14981 non-null  object
#  4   engagement                          8535 non-null   object
#  5   freelancers_to_hire                 14981 non-null  int64
#  6   amount_amount                       6446 non-null   float64
#  7   hourly_rate                         5764 non-null   float64
#  8   type                                14981 non-null  object
#  9   job_ts                              14981 non-null  float64
#  10  proposals_tier                      14981 non-null  object
# ...

# %%
df['published_on']
# Out:
# 0        2023-01-01T17:33:29Z
# 1        2023-01-01T17:38:19Z
# 2        2023-01-01T17:38:17Z
# 3        2023-01-01T17:38:03Z
# 4        2023-01-01T17:37:54Z
#                  ...
# 14976    2023-01-02T10:18:34Z
# 14977    2023-01-02T10:18:16Z
# 14978    2023-01-02T10:18:05Z
# 14979    2023-01-02T10:17:55Z
# 14980    2023-01-02T10:17:44Z
# Name: published_on, Length: 14981, dtype: object

# %%
df.isnull().sum()
# Out:
# connect_price                             0
# created_on                                0
# tz_date                                   0
# duration                                  0
# engagement                             6446
# freelancers_to_hire                       0
# amount_amount                          8535
# hourly_rate                            9217
# type                                      0
# job_ts                                    0
# proposals_tier                            0
# published_on                              0
# renewed_on                            14632
# tier                                      2
# title                                     0
# total_freelancers_to_hire                 0
# uid                                       0
# client_company_org_uid                    0
# client_payment_verification_status    10099
# client_total_feedback                     0
# client_total_reviews                      0
# ...

# %%
df.drop(columns=['engagement','job_ts','renewed_on','uid','tz_date','created_on','published_on'],inplace=True)

# %%
df.head(3)
# Out:
#    connect_price            duration  freelancers_to_hire  amount_amount  \
# 0              6  More than 6 months                    1            NaN
# 1              2   Less than 1 month                    1           30.0
# 2              4   Less than 1 month                    1          100.0
#
#    hourly_rate          type proposals_tier          tier  \
# 0         30.0        hourly    Less than 5  Intermediate
# 1          NaN  fixed_budget    Less than 5        Expert
# 2          NaN  fixed_budget    Less than 5        Expert
#
#                                                title  \
# 0                                       Zoom Webinar
# 1                   A page for a comic book (Page 9)
# 2  Looking for a graphic designer to brainstorm a...
#
#    total_freelancers_to_hire  ...  client_payment_verification_status  \
# 0                          1  ...                                 1.0
# 1                          1  ...                                 1.0
# ...

# %%
df.drop(columns=['weekly_budget_amount','weekly_budget_currency_code'],inplace=True)

# %%
df.tail(3)
# Out:
#        connect_price            duration  freelancers_to_hire  amount_amount  \
# 14978              6  More than 6 months                    1            NaN
# 14979              4       3 to 6 months                    2          250.0
# 14980              2       1 to 3 months                    2           25.0
#
#        hourly_rate          type proposals_tier         tier  \
# 14978          4.0        hourly            50+  Entry level
# 14979          NaN  fixed_budget        5 to 10       Expert
# 14980          NaN  fixed_budget       20 to 50  Entry level
#
#                                                    title  \
# 14978  Virtual Assistant to complete small tasks over...
# 14979  Go High Level GHL Workflow/Strategy - Australi...
# 14980                      YouTube Video Content Creator
#
#        total_freelancers_to_hire  client_company_org_uid  \
# 14978                          1            5.211975e+17
# 14979                          2            6.020036e+17
# ...

# %%
df.drop(columns=['client_company_org_uid','client_payment_verification_status'],inplace=True)

# %%
df.head(2)
# Out:
#    connect_price            duration  freelancers_to_hire  amount_amount  \
# 0              6  More than 6 months                    1            NaN
# 1              2   Less than 1 month                    1           30.0
#
#    hourly_rate          type proposals_tier          tier  \
# 0         30.0        hourly    Less than 5  Intermediate
# 1          NaN  fixed_budget    Less than 5        Expert
#
#                               title  total_freelancers_to_hire  \
# 0                      Zoom Webinar                          1
# 1  A page for a comic book (Page 9)                          1
#
#    client_total_feedback  client_total_reviews  client_total_spent  \
# 0                    0.0                     0                0.00
# 1                    5.0                    20             3817.42
#
#   client_location_country occupations_category_pref_label  \
# 0                  Canada                     Translation
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14981 entries, 0 to 14980
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   connect_price                    14981 non-null  int64
#  1   duration                         14981 non-null  object
#  2   freelancers_to_hire              14981 non-null  int64
#  3   amount_amount                    6446 non-null   float64
#  4   hourly_rate                      5764 non-null   float64
#  5   type                             14981 non-null  object
#  6   proposals_tier                   14981 non-null  object
#  7   tier                             14979 non-null  object
#  8   title                            14981 non-null  object
#  9   total_freelancers_to_hire        14981 non-null  int64
#  10  client_total_feedback            14981 non-null  float64
#  11  client_total_reviews             14981 non-null  int64
# ...

# %%
df.drop(columns=['connect_price','duration'],inplace=True)
df.tail(3)
# Out:
#        freelancers_to_hire  amount_amount  hourly_rate          type  \
# 14978                    1            NaN          4.0        hourly
# 14979                    2          250.0          NaN  fixed_budget
# 14980                    2           25.0          NaN  fixed_budget
#
#       proposals_tier         tier  \
# 14978            50+  Entry level
# 14979        5 to 10       Expert
# 14980       20 to 50  Entry level
#
#                                                    title  \
# 14978  Virtual Assistant to complete small tasks over...
# 14979  Go High Level GHL Workflow/Strategy - Australi...
# 14980                      YouTube Video Content Creator
#
#        total_freelancers_to_hire  client_total_feedback  client_total_reviews  \
# 14978                          1               4.715172                    61
# 14979                          2               4.740600                    37
# ...

# %%
df['client_location_country'].value_counts()
# Out:
# United States     5749
# United Kingdom    1267
# India             1106
# Canada             832
# Australia          733
#                   ...
# Honduras             1
# Ecuador              1
# Paraguay             1
# Reunion              1
# Saint Lucia          1
# Name: client_location_country, Length: 145, dtype: int64

# %%
df.groupby(by=['occupations_category_pref_label']).sum()[['total_freelancers_to_hire', 'client_total_reviews']]
# Out:
#                                  total_freelancers_to_hire  \
# occupations_category_pref_label
# Accounting & Consulting                                563
# Admin Support                                         2033
# Customer Service                                       317
# Data Science & Analytics                               461
# Design & Creative                                     3086
# Engineering & Architecture                             482
# IT & Networking                                        373
# Legal                                                  110
# Sales & Marketing                                     2921
# Translation                                            464
# Web, Mobile & Software Dev                            3808
# Writing                                               1971
#
#                                  client_total_reviews
# occupations_category_pref_label
# Accounting & Consulting                         18192
# ...

# %%
df.groupby(by=['client_location_country']).sum()[['total_freelancers_to_hire', 'client_total_reviews','client_total_feedback','client_total_spent']].head(20)
# Out:
#                          total_freelancers_to_hire  client_total_reviews  \
# client_location_country
# Albania                                          8                    49
# Algeria                                         16                    56
# American Samoa                                   6                    80
# Andorra                                          8                    19
# Antigua and Barbuda                              1                     1
# Argentina                                        7                   816
# Armenia                                          7                   132
# Australia                                      724                 24222
# Austria                                         52                   916
# Azerbaijan                                       8                    63
# Bahamas                                          2                    26
# ...

# %%
df.groupby(by=['occupations_category_pref_label']).sum()[['hourly_rate', 'total_freelancers_to_hire']]
# Out:
#                                  hourly_rate  total_freelancers_to_hire
# occupations_category_pref_label
# Accounting & Consulting              8613.50                        563
# Admin Support                        9140.25                       2033
# Customer Service                     1217.25                        317
# Data Science & Analytics             6243.00                        461
# Design & Creative                   22855.75                       3086
# Engineering & Architecture           4941.50                        482
# IT & Networking                      7946.50                        373
# Legal                                3823.75                        110
# Sales & Marketing                   29933.00                       2921
# Translation                          2471.00                        464
# Web, Mobile & Software Dev          38335.00                       3808
# Writing                             11906.25                       1971

# %%
df.groupby(by=['client_location_country']).sum()[['total_freelancers_to_hire', 'hourly_rate']].head(20)
# Out:
#                          total_freelancers_to_hire  hourly_rate
# client_location_country
# Albania                                          8        51.50
# Algeria                                         16       227.00
# American Samoa                                   6         0.00
# Andorra                                          8        25.00
# Antigua and Barbuda                              1         0.00
# Argentina                                        7        45.00
# Armenia                                          7        42.50
# Australia                                      724      8055.25
# Austria                                         52       621.50
# Azerbaijan                                       8        55.00
# Bahamas                                          2         0.00
# Bahrain                                         16        80.50
# Bangladesh                                     118      1453.00
# ...

# %%
df.groupby(by=['occupations_oservice_pref_label']).sum()[['hourly_rate']]
# Out:
#                                  hourly_rate
# occupations_oservice_pref_label
# 2D Animation                           546.5
# 3D Animation                           792.5
# 3D Modeling & Rendering                965.0
# A/B Testing                            280.0
# AR/VR Design                             0.0
# ...                                      ...
# Voice Talent                          1243.5
# Web & Software Product Research          8.0
# Web & UX Writing                        11.5
# Web Design                            5330.0
# Writing Tutoring                       141.0
#
# [208 rows x 1 columns]

# %%
df.groupby(by=['tier']).sum()[['hourly_rate','freelancers_to_hire']]
# Out:
#               hourly_rate  freelancers_to_hire
# tier
# Entry level      10569.50                 3518
# Expert           74611.00                 5292
# Intermediate     62246.25                 7775

# %%
df.groupby(by=['client_location_country','occupations_oservice_pref_label'], as_index=False).count()
# Out:
#      client_location_country occupations_oservice_pref_label  \
# 0                    Albania                 CMS Development
# 1                    Albania           Front-End Development
# 2                    Albania      General Virtual Assistance
# 3                    Albania                  Graphic Design
# 4                    Albania                     Logo Design
# ...                      ...                             ...
# 3213                  Zambia           Front-End Development
# 3214                  Zambia          Full Stack Development
# 3215                  Zambia                  Graphic Design
# 3216                  Zambia            Information Security
# 3217                  Zambia                    Voice Talent
#
#       freelancers_to_hire  amount_amount  hourly_rate  type  proposals_tier  \
# 0                       1              1            0     1               1
# 1                       1              0            0     1               1
# ...

# %%
df.groupby(by=['tier','proposals_tier'], as_index=False).count()
# Out:
#             tier proposals_tier  freelancers_to_hire  amount_amount  \
# 0    Entry level       10 to 15                  254            144
# 1    Entry level       15 to 20                  197            105
# 2    Entry level       20 to 50                  525            275
# 3    Entry level        5 to 10                  353            252
# 4    Entry level            50+                  279            142
# 5    Entry level    Less than 5                  523            344
# 6         Expert       10 to 15                  770            339
# 7         Expert       15 to 20                  567            229
# 8         Expert       20 to 50                 1344            515
# 9         Expert        5 to 10                  904            430
# 10        Expert            50+                  465            138
# 11        Expert    Less than 5                  907            443
# 12  Intermediate       10 to 15                 1167            462
# ...

# %%
df.groupby(by=['type']).sum()[['total_freelancers_to_hire','hourly_rate']]
# Out:
#               total_freelancers_to_hire  hourly_rate
# type
# fixed_budget                       8108         0.00
# hourly                             6538    147426.75
# no_budget                          1943         0.00
