# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import colorama
from colorama import Fore, Back, Style

# !pip install country_converter
import country_converter as coco

#ignoring warnings to keep the output clean
import warnings
warnings.filterwarnings('ignore')
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
job_df = pd.read_csv('ds_salaries.csv')
print(Back.BLUE+ Style.BRIGHT+'Data Science Job Salary Data:'+ Style.RESET_ALL)
job_df.head().style.set_properties(**{'background-color': '#D9EAD3' ,'color':'black','border-color': '#000000'})
job_df.head()
# Out:
# Data Science Job Salary Data:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# ...

# %%
print(Back.BLUE+ Style.BRIGHT+'Count of Null values:'+ Style.RESET_ALL)
na_df=job_df.isnull().sum().reset_index()
na_df.style.set_properties(**{'background-color': '#D9EAD3' ,'color':'black','border-color': '#000000'})
# Out:
# Count of Null values:
# <style type="text/css">
# #T_e6f17_row0_col0, #T_e6f17_row0_col1, #T_e6f17_row1_col0, #T_e6f17_row1_col1, #T_e6f17_row2_col0, #T_e6f17_row2_col1, #T_e6f17_row3_col0, #T_e6f17_row3_col1, #T_e6f17_row4_col0, #T_e6f17_row4_col1, #T_e6f17_row5_col0, #T_e6f17_row5_col1, #T_e6f17_row6_col0, #T_e6f17_row6_col1, #T_e6f17_row7_col0, #T_e6f17_row7_col1, #T_e6f17_row8_col0, #T_e6f17_row8_col1, #T_e6f17_row9_col0, #T_e6f17_row9_col1, #T_e6f17_row10_col0, #T_e6f17_row10_col1, #T_e6f17_row11_col0, #T_e6f17_row11_col1 {
#   background-color: #D9EAD3;
#   color: black;
#   border-color: #000000;
# }
# </style>
# <table id="T_e6f17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6f17_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_e6f17_level0_col1" class="col_heading level0 col1" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
